# %%
# %matplotlib inline
import numpy as np
import pandas as pd
from glob2 import glob
from pathlib import Path
from pdb import set_trace
import matplotlib.pyplot as plt
from scipy.stats import mannwhitneyu as ranksum

# Setup Matplotlib
# ----------------

# Font sizes
# ----------
SMALL_SIZE = 16
MEDIUM_SIZE = 20
BIGGER_SIZE = 36
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title


# Plot error rate comparisons and difference
# ------------------------------------------

plt.figure(figsize=(3,4))
data = np.array([[1, 49, 46, 49], [2, 49, 53, 47], [3, 33, 46, 36], [4, 16, 23, 23], [5, 58, 53, 53], [6, 66, 61, 57], [7, 66, 53, 59], [8, 49, 53, 47], [9, 16, 23, 23], [10, 58, 53, 53], [11, 74, 69, 59], [12, 66, 53, 59], [13, 33, 46, 36], [14, 8, 30, 11], [15, 49, 46, 49], [16, 58, 53, 53], [17, 58, 46, 55],[18, 58, 69, 49], [19, 24, 30, 31], [20, 66, 69, 55], [21, 58, 53, 53], [22, 66, 53, 59], [23, 49,61, 46], [24, 16, 23, 23], [25, 66, 53, 59], [26, 58, 53, 53], [27, 49, 53, 47], [28, 41, 46, 43],[29, 8, 23, 12], [30, 49, 46, 49]])
p_d = data[:, 1]
p_f = data[:, 2]
f_1 = data[:, 3]
plt.boxplot([p_d], labels=['Prob. Detection'])
plt.show()
plt.boxplot([p_f], labels=['Prob. False Alarm'])
plt.show()
plt.boxplot([f_1], labels=['F1'])
plt.show()
